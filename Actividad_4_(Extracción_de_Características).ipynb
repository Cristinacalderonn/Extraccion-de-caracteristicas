# %% [markdown]
# <a href="https://colab.research.google.com/github/Cristinacalderonn/Extraccion-de-caracteristicas/blob/main/Actividad_4_(Extracci%C3%B3n_de_Caracter%C3%ADsticas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Carga desde un archivo .xlsx sin indice
Micro_Retailer= pd.read_excel('microretailer_mit_lift_lab.xlsx')

# %%
#Verificamos información del DataFrame
Micro_Retailer.info()

# %%
#Imprimo los primeros 2 registro del dataframe
Micro_Retailer.head(2)

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(Micro_Retailer)

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['214_customer_relationship_tools'])
table1

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro

# %%
#Filtro por columnas
filtro1=Micro_Retailer.iloc[ : , [1,2,3,8,9,15,23,25,27,30,32,34,35,36,48,55,66,68,75,81]]
filtro1
# Out:
#                 _title       _server_updated_at           _updated_by  \
# 0    November 12, 2022  2022-11-12 22:15:10 UTC  Salomon Abdala Perez
# 1    November 12, 2022  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 2    November 12, 2022  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 3    November 12, 2022  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 4    November 12, 2022  2022-11-12 22:15:08 UTC  Salomon Abdala Perez
# ..                 ...                      ...                   ...
# 166   November 3, 2022  2022-11-03 16:50:48 UTC          Emilio Garza
# 167   November 3, 2022  2022-11-03 16:28:15 UTC          Emilio Garza
# 168   November 3, 2022  2022-11-03 16:28:14 UTC          Emilio Garza
# 169   November 3, 2022  2022-11-03 16:18:37 UTC        Francisco Adán
# 170   November 3, 2022  2022-11-03 16:15:13 UTC          Emilio Garza
#
#     229_store_picture                232_type_of_store  \
# 0             1 Photo                           Tailor
# 1             1 Photo   Grocery store (aka. nanostore)
# 2             1 Photo   Grocery store (aka. nanostore)
# 3             1 Photo   Grocery store (aka. nanostore)
# 4             1 Photo   Grocery store (aka. nanostore)
# ..                ...                              ...
# 166           1 Photo   Grocery store (aka. nanostore)
# 167           1 Photo   Grocery store (aka. nanostore)
# 168           1 Photo  Micro-restaurant (aka. fondita)
# 169           1 Photo  Micro-restaurant (aka. fondita)
# 170           1 Photo  Micro-restaurant (aka. fondita)
#
#                                      184_store_devices  \
# 0    POS system (i.e. computer + bar code scanner +...
# 1                       Dataphone (i.e. card payments)
# 2    Dataphone (i.e. card payments),POS system (i.e...
# 3    POS system (i.e. computer + bar code scanner +...
# 4                                           Smartphone
# ..                                                 ...
# 166                    Analog cash register,Smartphone
# 167                    Analog cash register,Smartphone
# 168                                         Smartphone
# 169                               Analog cash register
# 170                                         Smartphone
#
#     5_change_store_space_last_year 20_reviews_finances_monthly  \
# 0                        No cambió                         yes
# 1                      Aumentó 15%                         yes
# 2                        No cambió                         yes
# 3                        No cambió                         yes
# 4                        No cambió                         yes
# ..                             ...                         ...
# 166                            NaN                         NaN
# 167                            NaN                         NaN
# 168                            NaN                         NaN
# 169                            NaN                         NaN
# 170                            NaN                         NaN
#
#                          18_sales_records 19_tax_id 310_burnout  \
# 0    Software especializado + computadora       yes          no
# 1                              No lo hago        no          no
# 2    Software especializado + computadora        no          no
# 3    Software especializado + computadora       yes          no
# 4                                En papel       yes          no
# ..                                    ...       ...         ...
# 166                                   NaN       NaN         NaN
# 167                                   NaN       NaN         NaN
# 168                                   NaN       NaN         NaN
# 169                                   NaN       NaN         NaN
# 170                                   NaN       NaN         NaN
#
#     186_internet_connection  \
# 0                       yes
# 1                       yes
# 2                       yes
# 3                       yes
# 4                       yes
# ..                      ...
# 166                     NaN
# 167                     NaN
# 168                     NaN
# 169                     NaN
# 170                     NaN
#
#                                     210_sales_channels  \
# 0    Llamada a Teléfono celular,Llamada a Teléfono ...
# 1                                             WhatsApp
# 2    Redes sociales (e.g. Facebook, Instagram),What...
# 3                              Llamada a Teléfono fijo
# 4                           Llamada a Teléfono celular
# ..                                                 ...
# 166                                                NaN
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
#
#                                    189_payment_methods 33_credit_to_customers  \
# 0                 Efectivo,Transferencia interbancaria                     no
# 1                 Efectivo,Transferencia interbancaria                     no
# 2               Efectivo,Tarjeta de débito y/o crédito                    yes
# 3    Efectivo,Tarjeta de débito y/o crédito,Transfe...                     no
# 4    Efectivo,Tarjeta de débito y/o crédito,Transfe...                    yes
# ..                                                 ...                    ...
# 166                                                NaN                    NaN
# 167                                                NaN                    NaN
# 168                                                NaN                    NaN
# 169                                                NaN                    NaN
# 170                                                NaN                    NaN
#
#     60_services 311_topups 313_home_deliveries  \
# 0           NaN        NaN                 NaN
# 1           NaN        NaN                 NaN
# 2           NaN        NaN                 NaN
# 3           NaN        NaN                 NaN
# 4           NaN        NaN                 NaN
# ..          ...        ...                 ...
# 166         NaN        NaN                 NaN
# 167         NaN        NaN                 NaN
# 168         NaN        NaN                 NaN
# 169         NaN        NaN                 NaN
# 170         NaN        NaN                 NaN
#
#     43_willingness_share_sales_data_suppliers 278_credit_interest
# 0                                         NaN                 NaN
# 1                                         NaN                 NaN
# 2                                         NaN                 NaN
# 3                                         NaN                 NaN
# 4                                         NaN                 NaN
# ..                                        ...                 ...
# 166                                       NaN                 NaN
# 167                                       NaN                 NaN
# 168                                       NaN                 NaN
# 169                                       NaN                 NaN
# 170                                       NaN                 NaN
#
# [171 rows x 20 columns]

# %%
#Corroboramos valores nulos
valores_nulos=filtro1.isnull().sum()
valores_nulos

# %%
filtro1=filtro1.fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=filtro1.isnull().sum()
valores_nulos

# %%
filtro1.info()

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(filtro1)
# Out:
#               _title  frequency  percentage  cumulative_perc
# 0   November 9, 2022         73    0.426901         0.426901
# 1  November 10, 2022         26    0.152047         0.578947
# 2   November 7, 2022         20    0.116959         0.695906
# 3   November 3, 2022         16    0.093567         0.789474
# 4  November 12, 2022         15    0.087719         0.877193
# 5   November 8, 2022         10    0.058480         0.935673
# 6   November 4, 2022          9    0.052632         0.988304
# 7  November 11, 2022          1    0.005848         0.994152
# 8   November 2, 2022          1    0.005848         1.000000
#
# ----------------------------------------------------------------
#
#           _server_updated_at  frequency  percentage  cumulative_perc
# 0    2022-11-09 23:13:46 UTC          3    0.017544         0.017544
# 1    2022-11-11 22:11:34 UTC          3    0.017544         0.035088
# 2    2022-11-09 23:13:47 UTC          3    0.017544         0.052632
# 3    2022-11-12 22:15:09 UTC          3    0.017544         0.070175
# 4    2022-11-09 23:20:41 UTC          2    0.011696         0.081871
# ..                       ...        ...         ...              ...
# 127  2022-11-10 17:34:43 UTC          1    0.005848         0.976608
# 128  2022-11-10 17:34:47 UTC          1    0.005848         0.982456
# 129  2022-11-10 17:39:04 UTC          1    0.005848         0.988304
# 130  2022-11-10 17:46:56 UTC          1    0.005848         0.994152
# 131  2022-11-03 16:15:13 UTC          1    0.005848         1.000000
#
# [132 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                           _updated_by  frequency  percentage  cumulative_perc
# 0                Salomon Abdala Perez         20    0.116959         0.116959
# 1   Ángel Francisco Altamirano Campos         16    0.093567         0.210526
# 2                         José Zapata         14    0.081871         0.292398
# 3                        Emilio Garza         13    0.076023         0.368421
# 4                    Benjamin Barbosa         13    0.076023         0.444444
# 5                     Pedro Contreras         12    0.070175         0.514620
# 6                      Eduardo Zárate          9    0.052632         0.567251
# 7                    Alejandro Matias          8    0.046784         0.614035
# 8                     Harry Hernández          7    0.040936         0.654971
# 9                      Francisco Adán          7    0.040936         0.695906
# 10                      Hiram Jiménez          6    0.035088         0.730994
# 11                       Ismael López          6    0.035088         0.766082
# 12                      Mauro Munguía          4    0.023392         0.789474
# 13                         Alan Bravo          4    0.023392         0.812865
# 14                     Sandra Carreón          4    0.023392         0.836257
# 15                        Jorge Mason          3    0.017544         0.853801
# 16                      Jesús Herrera          3    0.017544         0.871345
# 17              Ricardo Galindo Bulos          3    0.017544         0.888889
# 18                         Yael Loeza          2    0.011696         0.900585
# 19                      Manuel Flores          2    0.011696         0.912281
# 20                       Juan Spínola          2    0.011696         0.923977
# 21                      Azael Mendoza          2    0.011696         0.935673
# 22             Irvin Vásquez Figueroa          2    0.011696         0.947368
# 23    Sebastian Salem Barranco Olvera          2    0.011696         0.959064
# 24      Jesús Antonio Zapatero García          1    0.005848         0.964912
# 25                   Marino Gutiérrez          1    0.005848         0.970760
# 26             Ramón Alberto Gastélum          1    0.005848         0.976608
# 27                        Saúl Cuervo          1    0.005848         0.982456
# 28                       José Oropeza          1    0.005848         0.988304
# 29                          Luis Lara          1    0.005848         0.994152
# 30                     Daniel Serrano          1    0.005848         1.000000
#
# ----------------------------------------------------------------
#
#   229_store_picture  frequency  percentage  cumulative_perc
# 0           1 Photo        166     0.97076          0.97076
# 1          2 Photos          5     0.02924          1.00000
#
# ----------------------------------------------------------------
#
#                   232_type_of_store  frequency  percentage  cumulative_perc
# 0    Grocery store (aka. nanostore)         52    0.304094         0.304094
# 1   Micro-restaurant (aka. fondita)         31    0.181287         0.485380
# 2                    Dairy products         10    0.058480         0.543860
# 3                         Cafeteria          6    0.035088         0.578947
# 4                      Butcher shop          6    0.035088         0.614035
# ..                              ...        ...         ...              ...
# 59                          joyeria          1    0.005848         0.976608
# 60                         dulceria          1    0.005848         0.982456
# 61                             Ropa          1    0.005848         0.988304
# 62                       Ferretería          1    0.005848         0.994152
# 63         productos tradicionales           1    0.005848         1.000000
#
# [64 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                                     184_store_devices  frequency  percentage  \
# 0                                          Smartphone         52    0.304094
# 1                                Analog cash register         16    0.093567
# 2   POS system (i.e. computer + bar code scanner +...          9    0.052632
# 3   POS system (i.e. computer + bar code scanner +...          9    0.052632
# 4                     Analog cash register,Smartphone          8    0.046784
# 5                         Security cameras,Smartphone          7    0.040936
# 6   Dataphone (i.e. card payments),Security camera...          5    0.029240
# 7                                    Security cameras          5    0.029240
# 8    Analog cash register,Security cameras,Smartphone          5    0.029240
# 9                      Dataphone (i.e. card payments)          4    0.023392
# 10  POS system (i.e. computer + bar code scanner +...          4    0.023392
# 11              Analog cash register,Security cameras          4    0.023392
# 12  Analog cash register,POS system (i.e. computer...          4    0.023392
# 13    Dataphone (i.e. card payments),Security cameras          3    0.017544
# 14  Analog cash register,POS system (i.e. computer...          3    0.017544
# 15          Dataphone (i.e. card payments),Smartphone          3    0.017544
# 16  Dataphone (i.e. card payments),POS system (i.e...          3    0.017544
# 17  Dataphone (i.e. card payments),POS system (i.e...          2    0.011696
# 18  POS system (i.e. computer + bar code scanner +...          2    0.011696
# 19  Analog cash register,Dataphone (i.e. card paym...          2    0.011696
# 20  Analog cash register,Dataphone (i.e. card paym...          2    0.011696
# 21  Analog cash register,Dataphone (i.e. card paym...          2    0.011696
# 22  Dataphone (i.e. card payments),POS system (i.e...          2    0.011696
# 23  POS system (i.e. computer + bar code scanner +...          1    0.005848
# 24  Dataphone (i.e. card payments),POS system (i.e...          1    0.005848
# 25  Analog cash register,Dataphone (i.e. card paym...          1    0.005848
# 26  Analog cash register,Dataphone (i.e. card paym...          1    0.005848
# 27                                           Nothing           1    0.005848
# 28                          acepta pagos en efectivo           1    0.005848
# 29  Analog cash register,POS system (i.e. computer...          1    0.005848
# 30                                 Pesa y calculadora          1    0.005848
# 31                        no cuenta con dispositivos           1    0.005848
# 32                                            ninguno          1    0.005848
# 33                                    Papel y celular          1    0.005848
# 34               Security cameras,bocina y ventilador          1    0.005848
# 35  Analog cash register,Dataphone (i.e. card paym...          1    0.005848
# 36                                                 no          1    0.005848
# 37                                           no tiene          1    0.005848
#
#     cumulative_perc
# 0          0.304094
# 1          0.397661
# 2          0.450292
# 3          0.502924
# 4          0.549708
# 5          0.590643
# 6          0.619883
# 7          0.649123
# 8          0.678363
# 9          0.701754
# 10         0.725146
# 11         0.748538
# 12         0.771930
# 13         0.789474
# 14         0.807018
# 15         0.824561
# 16         0.842105
# 17         0.853801
# 18         0.865497
# 19         0.877193
# 20         0.888889
# 21         0.900585
# 22         0.912281
# 23         0.918129
# 24         0.923977
# 25         0.929825
# 26         0.935673
# 27         0.941520
# 28         0.947368
# 29         0.953216
# 30         0.959064
# 31         0.964912
# 32         0.970760
# 33         0.976608
# 34         0.982456
# 35         0.988304
# 36         0.994152
# 37         1.000000
#
# ----------------------------------------------------------------
#
#   5_change_store_space_last_year  frequency  percentage  cumulative_perc
# 0                      No cambió        122    0.713450         0.734940
# 1                  Disminuyó 15%         15    0.087719         0.825301
# 2                    Aumentó 25%         11    0.064327         0.891566
# 3              Aumentó 50% o más          9    0.052632         0.945783
# 4                    Aumentó 15%          4    0.023392         0.969880
# 5            Disminuyó 50% o más          3    0.017544         0.987952
# 6                  Disminuyó 25%          2    0.011696         1.000000
#
# ----------------------------------------------------------------
#
#   20_reviews_finances_monthly  frequency  percentage  cumulative_perc
# 0                         yes        122     0.71345          0.73494
# 1                          no         44     0.25731          1.00000
#
# ----------------------------------------------------------------
#
#                                      18_sales_records  frequency  percentage  \
# 0                                            En papel         62    0.362573
# 1                Software especializado + computadora         26    0.152047
# 2                                          No lo hago         24    0.140351
# 3                                            En Excel         21    0.122807
# 4                                   En Excel,En papel         12    0.070175
# 5                         Caja registradora (análoga)          6    0.035088
# 6   Aplicación móvil (i.e. App) + smartphone,Caja ...          5    0.029240
# 7       Caja registradora (análoga),En Excel,En papel          3    0.017544
# 8            Aplicación móvil (i.e. App) + smartphone          1    0.005848
# 9   Aplicación móvil (i.e. App) + smartphone,Caja ...          1    0.005848
# 10                                          Contadora          1    0.005848
# 11                                             Notas           1    0.005848
# 12  Aplicación móvil (i.e. App) + smartphone,Softw...          1    0.005848
# 13      En Excel,Software especializado + computadora          1    0.005848
# 14  Aplicación móvil (i.e. App) + smartphone,En Ex...          1    0.005848
#
#     cumulative_perc
# 0          0.373494
# 1          0.530120
# 2          0.674699
# 3          0.801205
# 4          0.873494
# 5          0.909639
# 6          0.939759
# 7          0.957831
# 8          0.963855
# 9          0.969880
# 10         0.975904
# 11         0.981928
# 12         0.987952
# 13         0.993976
# 14         1.000000
#
# ----------------------------------------------------------------
#
#   19_tax_id  frequency  percentage  cumulative_perc
# 0       yes        108    0.631579         0.650602
# 1        no         58    0.339181         1.000000
#
# ----------------------------------------------------------------
#
#   310_burnout  frequency  percentage  cumulative_perc
# 0          no         93    0.543860         0.560241
# 1         yes         73    0.426901         1.000000
#
# ----------------------------------------------------------------
#
#   186_internet_connection  frequency  percentage  cumulative_perc
# 0                     yes        118    0.690058         0.710843
# 1                      no         48    0.280702         1.000000
#
# ----------------------------------------------------------------
#
#                                    210_sales_channels  frequency  percentage  \
# 0   Redes sociales (e.g. Facebook, Instagram),What...         26    0.152047
# 1           Redes sociales (e.g. Facebook, Instagram)         20    0.116959
# 2                                            WhatsApp         17    0.099415
# 3                             Llamada a Teléfono fijo         12    0.070175
# 4                         conocidos paquetes cerrados         10    0.058480
# 5                 Llamada a Teléfono celular,WhatsApp          8    0.046784
# 6                          Llamada a Teléfono celular          7    0.040936
# 7                          Página web propia,WhatsApp          7    0.040936
# 8   Llamada a Teléfono celular,Redes sociales (e.g...          7    0.040936
# 9   Página web propia,Redes sociales (e.g. Faceboo...          7    0.040936
# 10  Llamada a Teléfono fijo,Redes sociales (e.g. F...          6    0.035088
# 11                                  Página web propia          5    0.029240
# 12                                            Ninguno          5    0.029240
# 13  Llamada a Teléfono celular,Página web propia,R...          4    0.023392
# 14  Llamada a Teléfono celular,Llamada a Teléfono ...          4    0.023392
# 15                                       Solo físico           3    0.017544
# 16  Aplicación móvil (e.g. Rappi, Uber Eats),Llama...          3    0.017544
# 17                                                 no          2    0.011696
# 18           Aplicación móvil (e.g. Rappi, Uber Eats)          2    0.011696
# 19  Llamada a Teléfono celular,Llamada a Teléfono ...          2    0.011696
# 20  Página web propia,Redes sociales (e.g. Faceboo...          1    0.005848
# 21  Aplicación móvil (e.g. Rappi, Uber Eats),Llama...          1    0.005848
# 22                                            Físico           1    0.005848
# 23                   Llamada a Teléfono fijo,WhatsApp          1    0.005848
# 24                                           Volantes          1    0.005848
# 25  Aplicación móvil (e.g. Rappi, Uber Eats),Llama...          1    0.005848
# 26  Llamada a Teléfono celular,Llamada a Teléfono ...          1    0.005848
# 27  Llamada a Teléfono celular,Llamada a Teléfono ...          1    0.005848
# 28  Llamada a Teléfono fijo,Redes sociales (e.g. F...          1    0.005848
#
#     cumulative_perc
# 0          0.156627
# 1          0.277108
# 2          0.379518
# 3          0.451807
# 4          0.512048
# 5          0.560241
# 6          0.602410
# 7          0.644578
# 8          0.686747
# 9          0.728916
# 10         0.765060
# 11         0.795181
# 12         0.825301
# 13         0.849398
# 14         0.873494
# 15         0.891566
# 16         0.909639
# 17         0.921687
# 18         0.933735
# 19         0.945783
# 20         0.951807
# 21         0.957831
# 22         0.963855
# 23         0.969880
# 24         0.975904
# 25         0.981928
# 26         0.987952
# 27         0.993976
# 28         1.000000
#
# ----------------------------------------------------------------
#
#                                  189_payment_methods  frequency  percentage  \
# 0                                           Efectivo         64    0.374269
# 1  Efectivo,Tarjeta de débito y/o crédito,Transfe...         49    0.286550
# 2             Efectivo,Tarjeta de débito y/o crédito         30    0.175439
# 3               Efectivo,Transferencia interbancaria         20    0.116959
# 4  Aplicación móvil (e.g. CODI),Efectivo,Tarjeta ...          1    0.005848
# 5  Aplicación móvil (e.g. CODI),Efectivo,Tarjeta ...          1    0.005848
# 6                      Tarjeta de débito y/o crédito          1    0.005848
#
#    cumulative_perc
# 0         0.385542
# 1         0.680723
# 2         0.861446
# 3         0.981928
# 4         0.987952
# 5         0.993976
# 6         1.000000
#
# ----------------------------------------------------------------
#
#   33_credit_to_customers  frequency  percentage  cumulative_perc
# 0                     no        130    0.760234         0.783133
# 1                    yes         36    0.210526         1.000000
#
# ----------------------------------------------------------------
#
#                                           60_services  frequency  percentage  \
# 0                                             Ninguno        106    0.619883
# 1                                  Recarga telefónica         18    0.105263
# 2                                 Entrega a domicilio         17    0.099415
# 3   Entrega a domicilio,Pago de servicios públicos...          9    0.052632
# 4   Pago de servicios públicos (e.g. Yastas),Recar...          5    0.029240
# 5   Recepción y entrega de paquetes (e.g. Amazon, ...          3    0.017544
# 6   Entrega a domicilio,Pago de servicios públicos...          2    0.011696
# 7              Entrega a domicilio,Recarga telefónica          2    0.011696
# 8                                Toma de papa nicolau          1    0.005848
# 9                                      Renta de local          1    0.005848
# 10                                              venta          1    0.005848
# 11  Entrega a domicilio,Recarga telefónica,Recepci...          1    0.005848
#
#     cumulative_perc
# 0          0.638554
# 1          0.746988
# 2          0.849398
# 3          0.903614
# 4          0.933735
# 5          0.951807
# 6          0.963855
# 7          0.975904
# 8          0.981928
# 9          0.987952
# 10         0.993976
# 11         1.000000
#
# ----------------------------------------------------------------
#
#                        311_topups  frequency  percentage  cumulative_perc
# 0        Totalmente en desacuerdo         91    0.532164         0.548193
# 1           Totalmente de acuerdo         45    0.263158         0.819277
# 2              Algo en desacuerdo         14    0.081871         0.903614
# 3                 Algo de acuerdo          8    0.046784         0.951807
# 4  Ni de acuerdo ni en desacuerdo          8    0.046784         1.000000
#
# ----------------------------------------------------------------
#
#               313_home_deliveries  frequency  percentage  cumulative_perc
# 0        Totalmente en desacuerdo         73    0.426901         0.439759
# 1                 Algo de acuerdo         41    0.239766         0.686747
# 2           Totalmente de acuerdo         34    0.198830         0.891566
# 3              Algo en desacuerdo         13    0.076023         0.969880
# 4  Ni de acuerdo ni en desacuerdo          5    0.029240         1.000000
#
# ----------------------------------------------------------------
#
#   43_willingness_share_sales_data_suppliers  frequency  percentage  \
# 0                  Totalmente en desacuerdo        112    0.654971
# 1                        Algo en desacuerdo         26    0.152047
# 2                           Algo de acuerdo         11    0.064327
# 3                     Totalmente de acuerdo          9    0.052632
# 4            Ni de acuerdo ni en desacuerdo          8    0.046784
#
#    cumulative_perc
# 0         0.674699
# 1         0.831325
# 2         0.897590
# 3         0.951807
# 4         1.000000
#
# ----------------------------------------------------------------
#
#   278_credit_interest  frequency  percentage  cumulative_perc
# 0                   0        138    0.807018         0.831325
# 1                 9%+         12    0.070175         0.903614
# 2                3-5%          8    0.046784         0.951807
# 3                1-2%          6    0.035088         0.987952
# 4                6-8%          2    0.011696         1.000000
#
# ----------------------------------------------------------------

# %%
pd.options.display.max_columns = None

# %%
#Análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['_title'])
table1

# %%
#Filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>1]
Filtro2

# %%
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('_title')
Filtro_index1

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index1.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('_title')
plt.xlabel('')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
#Análisis univariado de una variable categórica en específico 1
table1= freq_tbl(Micro_Retailer['_server_updated_at'])
table1

# %%
#Filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>1]
Filtro2

# %%
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('_server_updated_at')
Filtro_index1

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index1.plot(kind='area', figsize=(20,16),alpha = 0.5)
# Out:
# <Axes: xlabel='_server_updated_at'>

# %%
#Análisis univariado de una variable categórica en específico 2
table1= freq_tbl(Micro_Retailer['_updated_by'])
table1

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>1]
Filtro2

# %%
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('_updated_by')
Filtro_index1

# %%
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index1.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['229_store_picture'])
table1

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2

# %%
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('229_store_picture')
Filtro_index1

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['108_does_the_micro_retailer_has_a_barred_window_'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('108_does_the_micro_retailer_has_a_barred_window_')
Filtro_index1
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index1.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['214_customer_relationship_tools'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('214_customer_relationship_tools')
Filtro_index1
#Realizamos grafico de área del dataframe filtrado
Filtro_index1.plot(kind='area', figsize=(20,16),alpha = 0.5)
# Out:
# <Axes: xlabel='214_customer_relationship_tools'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['5_change_store_space_last_year'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('5_change_store_space_last_year')
Filtro_index1
#Realizamos grafico de barras del dataframe filtrado
Filtro_index1.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('5_change_store_space_last_year')
plt.xlabel('')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
#Obtengo un análisis univariado de una variable categórica en específico 7
table1= freq_tbl(Micro_Retailer['184_store_devices'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('184_store_devices')
Filtro_index1
#Realizamos grafico de área del dataframe filtrado
Filtro_index1.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='184_store_devices'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['19_tax_id'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('19_tax_id')
Filtro_index1
#Realizamos grafico de área del dataframe filtrado
Filtro_index1.plot(kind='area', figsize=(20,16),alpha = 0.5)
# Out:
# <Axes: xlabel='19_tax_id'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['18_sales_records'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('18_sales_records')
Filtro_index1
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index1.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico 10
table1= freq_tbl(Micro_Retailer['313_home_deliveries'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('313_home_deliveries')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico 11
table1= freq_tbl(Micro_Retailer['311_topups'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('311_topups')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['189_payment_methods'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('189_payment_methods')
Filtro_index1
#Realizamos grafico de barras del dataframe filtrado
Filtro_index1.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('189_payment_methods')
plt.xlabel('')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['210_sales_channels'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('210_sales_channels')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico 12
table1= freq_tbl(Micro_Retailer["60_services"])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('60_services')
Filtro_index1
#Realizamos grafico de barras del dataframe filtrado
Filtro_index1.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico 13
table1= freq_tbl(Micro_Retailer['33_credit_to_customers'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('33_credit_to_customers')
Filtro_index1

#Realizamos grafico de área del dataframe filtrado
Filtro_index1.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='33_credit_to_customers'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico 15
table1= freq_tbl(Micro_Retailer['210_sales_channels'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('210_sales_channels')
Filtro_index1
#Realizamos grafico de barras del dataframe filtrado
Filtro_index1.plot(kind = 'bar', width=1, figsize=(20,10))
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico 18
table1= freq_tbl(Micro_Retailer['19_tax_id'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('19_tax_id')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico 17
table1= freq_tbl(Micro_Retailer['310_burnout'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('310_burnout')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico 20
table1= freq_tbl(Micro_Retailer['20_reviews_finances_monthly'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('20_reviews_finances_monthly')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico 4
table1= freq_tbl(Micro_Retailer['47_willingness_reorder_suppliers_lower_prices'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table1[table1['frequency']>=1]
Filtro2
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro2.set_index('47_willingness_reorder_suppliers_lower_prices')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>
